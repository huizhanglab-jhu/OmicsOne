# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# from gpnotebook.tools.standard_imports import *
import os, re,sys
import yaml
import pandas as pd
import numpy as np

# %%
wd = r"C:\Users\yhu39\OneDrive - Johns Hopkins\project\2025_HN-Lung\google\Head and Neck & Lung\LSCC"

# %%
rna_path = os.path.join(wd, "LSCC_RNAseq_circRNA_RSEM_UQ_log2_Tumor.txt")
cnv_path = os.path.join(wd, "LSCC_WES_CNV_gene_ratio_log2.txt")

# %%
rna_data = pd.read_csv(rna_path, sep="\t", index_col=0)
cnv_data = pd.read_csv(cnv_path, sep="\t", index_col=0)

# %%
rna_data
# Out:
#                                                    C3L-00081  C3L-00415  \
# idx
# circ_chr10_100923975_100926019_ENSG00000119906.13       0.00       7.37
# circ_chr10_101667886_101676436_ENSG00000107829.15       6.86       6.14
# circ_chr10_101792839_101810314_ENSG00000198408.14       0.00       0.00
# circ_chr10_103622470_103661114_ENSG00000107957.16       0.00       0.00
# circ_chr10_110124017_110130486_ENSG00000148700.15       0.00       0.00
# ...                                                      ...        ...
# circ_chr7_50669722_50703908_ENSG00000106070.20          0.00       0.00
# circ_chrX_133753482_133754176_ENSG00000147257.15        0.00       0.00
# circ_chr11_65502321_65504595_ENSG00000251562.8          0.00       0.00
# circ_chr11_65502321_65505019_ENSG00000251562.8          0.00       0.00
# circ_chr3_58130741_58143613_ENSG00000136068.15          0.00       0.00
#
#                                                    C3L-00445  C3L-00568  \
# idx
# ...

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt
fig,ax = plt.subplots(figsize=(40, 6))
sns.boxplot(data=rna_data)
# Out:
# <Axes: >

# %%
rna_data.median()
# Out:
# C3L-00081    0.0
# C3L-00415    0.0
# C3L-00445    0.0
# C3L-00568    0.0
# C3L-00603    0.0
#             ...
# C3N-03886    0.0
# C3N-04124    0.0
# C3N-04127    0.0
# C3N-04155    0.0
# C3N-04162    0.0
# Length: 108, dtype: float64

# %%
cnv_data.median().min()
# Out:
# np.float64(-0.072)

# %%
import matplotlib.pyplot as plt
fig,ax = plt.subplots(figsize=(40, 6))
sns.boxplot(data=cnv_data)
# Out:
# <Axes: >
