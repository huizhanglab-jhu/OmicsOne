# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import sys
sys.path.append("/home/yingwei/newdrive/bitbucket/omicsone")

# %%
from omicsone import omicsone

# %%
options = {'parameter':'/home/yingwei/newdrive/bitbucket/omicsone/omicsone/params/param.txt'}
args = []

# %%
omicsone.run(options,args)
# Out:
# FILE_EXISTENCE_CHECK: input=/home/yingwei/newdrive/bitbucket/omicsone/omicsone/tools/../res/sample_data/phenotype_table.xlsx,result=SUCCESS
# FILE_EXISTENCE_CHECK: input=/home/yingwei/newdrive/bitbucket/omicsone/omicsone/tools/../res/sample_data/TCGA_Ovarian_JHU_Proteome.itraq.preprocessed.demo.csv,result=SUCCESS
# call import_data_by_file_name():{'file_name': '/home/yingwei/newdrive/bitbucket/omicsone/omicsone/tools/../res/sample_data/phenotype_table.xlsx', 'param': {'index': 'bcr_patient_barcode'}},SUCCESS
# call preprocess():{'file_name': '/home/yingwei/newdrive/bitbucket/omicsone/omicsone/tools/../res/sample_data/phenotype_table.xlsx', 'param': {'index': 'bcr_patient_barcode'}},SUCCESS
# ...

# %%
# %tb
# Out:
# ---------------------------------------------------------------------------
# SystemExit                                Traceback (most recent call last)
# <ipython-input-6-cd33f0317ca3> in <module>
# ----> 1 omicsone.run(options,args)
#
# ~/newdrive/bitbucket/omicsone/omicsone/omicsone.py in run(options, args)
#     160             run_cancersubtypes(df, info_df, cluster_param)
#     161
# --> 162     sys.exit(0)
#     163
#     164
#
# SystemExit: 0
